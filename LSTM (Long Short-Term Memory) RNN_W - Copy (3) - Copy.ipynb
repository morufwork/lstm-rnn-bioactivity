# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Read the csv from file to variable df

#df = pd.read_csv('finalData.csv')
df = pd.read_csv('finalData.csv')

# %%
sns.set(style='ticks')
plt.figure(figsize=(5.5, 5.5))

sns.countplot(x='class', data=df, edgecolor='black')

plt.xlabel('Bioactivity class', fontsize=14, fontweight='bold')
plt.ylabel('Frequency', fontsize=14, fontweight='bold')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
X = df['canonical_smiles']
y = df['class']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.model_selection import train_test_split
# Out:
# WARNING:tensorflow:From C:\Users\DELL\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Tokenize the SMILES strings
tokenizer = Tokenizer(char_level=True, lower=False)
tokenizer.fit_on_texts(X)
X_encoded = tokenizer.texts_to_sequences(X)

# %%
# After fitting tokenizer during training
import pickle
with open('tokenizer2.pkl', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Pad sequences to have the same length
#X_padded = pad_sequences(X_encoded)
X_padded = pad_sequences(X_encoded)

# %%
print(X_padded.shape)
# Out:
# (4620, 181)

# %%
# Data Splitting
X_train, X_test, y_train, y_test = train_test_split(X_padded, y, test_size=0.2, random_state=42)

# %%
#vocab_size = len(token_to_index) + 1 
vocab_size = len(tokenizer.word_index) + 1

# %%
from tensorflow.keras.layers import Dropout, ActivityRegularization
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.regularizers import l2

# Model Architecture
model = Sequential()

# Embedding layer
model.add(Embedding(input_dim=vocab_size, output_dim=64, input_length=X_padded.shape[1]))
model.add(BatchNormalization())


model.add(LSTM(32))
model.add(BatchNormalization())
model.add(Dropout(0.2))  # Example dropout layer

# Fully connected layer
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.02)))  # Example L2 regularization
model.add(Dropout(0.5))  # Additional dropout layer

# Output layer
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\DELL\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Print the model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 181, 64)           2496
#
#  batch_normalization (Batch  (None, 181, 64)           256
#  Normalization)
#
#  lstm (LSTM)                 (None, 32)                12416
#
#  batch_normalization_1 (Bat  (None, 32)                128
#  chNormalization)
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 17473 (68.25 KB)
# Trainable params: 17281 (67.50 KB)
# Non-trainable params: 192 (768.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import AUC


# Model Compilation
optimizer = Adam(learning_rate=0.0005, clipvalue=1.0)  # Adjust clipnorm as needed
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy', AUC(name='auc')])

# %%
from sklearn.metrics import log_loss, accuracy_score
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Lists to store training and validation loss values
train_losses = []
val_losses = []

train_accuracies = []
val_accuracies = []

# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=3, verbose=1, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=2,
    min_lr=1e-6,
    verbose=1
)

# Training loop
epochs = 30
for epoch in range(epochs):
    history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=1, batch_size=32, verbose=1, callbacks=[early_stopping, reduce_lr])

    # Predict on training and test set
    y_train_pred = model.predict(X_train, verbose=0)
    y_test_pred = model.predict(X_test, verbose=0)

    # Compute log loss
    train_loss = log_loss(y_train, y_train_pred)
    val_loss = log_loss(y_test, y_test_pred)

    train_losses.append(train_loss)
    val_losses.append(val_loss)
    
    
    # Convert probabilities to class labels
    y_train_classes = (y_train_pred > 0.5).astype(int)
    y_test_classes = (y_test_pred > 0.5).astype(int)

    # Compute accuracy
    train_acc = accuracy_score(y_train, y_train_classes)
    val_acc = accuracy_score(y_test, y_test_classes)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    
    
    

    print(f'Epoch {epoch + 1}/{epochs}, Training Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
# Out:
# WARNING:tensorflow:From C:\Users\DELL\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\DELL\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 116/116 [==============================] - 8s 45ms/step - loss: 1.4827 - accuracy: 0.5611 - auc: 0.5776 - val_loss: 1.3227 - val_accuracy: 0.4556 - val_auc: 0.4904 - lr: 5.0000e-04
# Epoch 1/30, Training Loss: 0.6958, Val Loss: 0.6948
# 116/116 [==============================] - 4s 39ms/step - loss: 1.2002 - accuracy: 0.6066 - auc: 0.6435 - val_loss: 1.1666 - val_accuracy: 0.4600 - val_auc: 0.5179 - lr: 5.0000e-04
# Epoch 2/30, Training Loss: 0.7188, Val Loss: 0.7112
# 116/116 [==============================] - 4s 38ms/step - loss: 1.0160 - accuracy: 0.6534 - auc: 0.6979 - val_loss: 1.0122 - val_accuracy: 0.5963 - val_auc: 0.6372 - lr: 5.0000e-04
# Epoch 3/30, Training Loss: 0.6776, Val Loss: 0.6785
# 116/116 [==============================] - 5s 39ms/step - loss: 0.8856 - accuracy: 0.6826 - auc: 0.7332 - val_loss: 0.8832 - val_accuracy: 0.6494 - val_auc: 0.7353 - lr: 5.0000e-04
# Epoch 4/30, Training Loss: 0.6306, Val Loss: 0.6371
# 116/116 [==============================] - 5s 40ms/step - loss: 0.7733 - accuracy: 0.7102 - auc: 0.7758 - val_loss: 0.8069 - val_accuracy: 0.6320 - val_auc: 0.7781 - lr: 5.0000e-04
# Epoch 5/30, Training Loss: 0.5909, Val Loss: 0.6219
# 116/116 [==============================] - 5s 39ms/step - loss: 0.7029 - accuracy: 0.7286 - auc: 0.7957 - val_loss: 0.6863 - val_accuracy: 0.7197 - val_auc: 0.8207 - lr: 5.0000e-04
# Epoch 6/30, Training Loss: 0.5240, Val Loss: 0.5466
# 116/116 [==============================] - 5s 40ms/step - loss: 0.6466 - accuracy: 0.7486 - auc: 0.8144 - val_loss: 0.7126 - val_accuracy: 0.6537 - val_auc: 0.8236 - lr: 5.0000e-04
# Epoch 7/30, Training Loss: 0.5682, Val Loss: 0.6056
# 116/116 [==============================] - 4s 38ms/step - loss: 0.6052 - accuracy: 0.7516 - auc: 0.8240 - val_loss: 0.6506 - val_accuracy: 0.7175 - val_auc: 0.8330 - lr: 5.0000e-04
# Epoch 8/30, Training Loss: 0.5196, Val Loss: 0.5667
# 116/116 [==============================] - 4s 39ms/step - loss: 0.5796 - accuracy: 0.7557 - auc: 0.8284 - val_loss: 0.5994 - val_accuracy: 0.7457 - val_auc: 0.8469 - lr: 5.0000e-04
# Epoch 9/30, Training Loss: 0.4914, Val Loss: 0.5340
# 116/116 [==============================] - 4s 38ms/step - loss: 0.5452 - accuracy: 0.7698 - auc: 0.8436 - val_loss: 0.5265 - val_accuracy: 0.7803 - val_auc: 0.8546 - lr: 5.0000e-04
# Epoch 10/30, Training Loss: 0.4448, Val Loss: 0.4744
# 116/116 [==============================] - 4s 39ms/step - loss: 0.5264 - accuracy: 0.7684 - auc: 0.8494 - val_loss: 0.4964 - val_accuracy: 0.7814 - val_auc: 0.8689 - lr: 5.0000e-04
# Epoch 11/30, Training Loss: 0.4284, Val Loss: 0.4534
# 116/116 [==============================] - 5s 39ms/step - loss: 0.5052 - accuracy: 0.7871 - auc: 0.8598 - val_loss: 0.4878 - val_accuracy: 0.7922 - val_auc: 0.8736 - lr: 5.0000e-04
# Epoch 12/30, Training Loss: 0.4206, Val Loss: 0.4526
# 116/116 [==============================] - 4s 38ms/step - loss: 0.4831 - accuracy: 0.7895 - auc: 0.8683 - val_loss: 0.5313 - val_accuracy: 0.7565 - val_auc: 0.8712 - lr: 5.0000e-04
# 116/116 [==============================] - 4s 39ms/step - loss: 0.3784 - accuracy: 0.8471 - auc: 0.9157 - val_loss: 0.3862 - val_accuracy: 0.8355 - val_auc: 0.9127 - lr: 5.0000e-04
# Epoch 24/30, Training Loss: 0.3038, Val Loss: 0.3739
# 116/116 [==============================] - 5s 39ms/step - loss: 0.3656 - accuracy: 0.8571 - auc: 0.9218 - val_loss: 0.4040 - val_accuracy: 0.8214 - val_auc: 0.9133 - lr: 5.0000e-04
# Epoch 25/30, Training Loss: 0.3200, Val Loss: 0.3925
# 116/116 [==============================] - 5s 39ms/step - loss: 0.3671 - accuracy: 0.8569 - auc: 0.9205 - val_loss: 0.3840 - val_accuracy: 0.8474 - val_auc: 0.9123 - lr: 5.0000e-04
# Epoch 26/30, Training Loss: 0.2949, Val Loss: 0.3732
# 116/116 [==============================] - 5s 40ms/step - loss: 0.3585 - accuracy: 0.8558 - auc: 0.9238 - val_loss: 0.4016 - val_accuracy: 0.8301 - val_auc: 0.9142 - lr: 5.0000e-04
# Epoch 27/30, Training Loss: 0.3059, Val Loss: 0.3903
# 116/116 [==============================] - 4s 38ms/step - loss: 0.3547 - accuracy: 0.8558 - auc: 0.9259 - val_loss: 0.3765 - val_accuracy: 0.8409 - val_auc: 0.9182 - lr: 5.0000e-04
# Epoch 28/30, Training Loss: 0.2839, Val Loss: 0.3656
# 116/116 [==============================] - 4s 38ms/step - loss: 0.3467 - accuracy: 0.8569 - auc: 0.9292 - val_loss: 0.3829 - val_accuracy: 0.8333 - val_auc: 0.9161 - lr: 5.0000e-04
# Epoch 29/30, Training Loss: 0.2946, Val Loss: 0.3716
# 116/116 [==============================] - 5s 39ms/step - loss: 0.3287 - accuracy: 0.8650 - auc: 0.9376 - val_loss: 0.4228 - val_accuracy: 0.8268 - val_auc: 0.9150 - lr: 5.0000e-04
# Epoch 30/30, Training Loss: 0.3290, Val Loss: 0.4102

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)
# Out:
# 29/29 [==============================] - 0s 12ms/step

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Use the predict method to get probabilities
y_pred_prob = model.predict(X_test)

# Threshold probabilities to get predicted classes (assuming binary classification)
y_pred = (y_pred_prob > 0.5).astype(int)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# 29/29 [==============================] - 0s 11ms/step
# Test Accuracy: 0.8268

# %%
# Plot confusion matrix
from sklearn.metrics import ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred, labels=[0, 1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['class_0', 'class_1'])
disp.plot(cmap=plt.cm.Blues, values_format='.2f')

# Add a title
plt.title('Normalized Confusion Matrix')

plt.show()

# %%
# Generate a classification report
class_report = classification_report(y_test, y_pred)
print("Classification Report:\n", class_report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.90      0.83       425
#            1       0.90      0.76      0.83       499
#
#     accuracy                           0.83       924
#    macro avg       0.83      0.83      0.83       924
# weighted avg       0.84      0.83      0.83       924

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# True binary labels
y_true = y_test

# Compute ROC curve and ROC area
fpr, tpr, thresholds = roc_curve(y_true, y_pred_prob)
roc_auc = auc(fpr, tpr)

# Plot
plt.figure()
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

# %%
# Plotting curves
plt.figure(figsize=(12, 5))

# Loss Curve
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Training Loss', marker='o')
plt.plot(val_losses, label='Validation Loss', marker='o')
plt.title('Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Log Loss')
plt.legend()

# Accuracy Curve
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Training Accuracy', marker='o')
plt.plot(val_accuracies, label='Validation Accuracy', marker='o')
plt.title('Accuracy Curve')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
model.save('lstm_model.h3')
model.save('saved_model/my_model3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.save('lstm_model.h3')
#       2 model.save('saved_model/my_model3')
#
# NameError: name 'model' is not defined
